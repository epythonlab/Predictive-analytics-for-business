# %% [markdown]
# # A/B Test: A New Menu Launch

# %% [markdown]
# ## Step 1: Plan Your Analysis
#
# To perform the correct analysis, you will need to prepare a data set. Prior to rolling up your sleeves and preparing the data, it’s a good idea to have a plan of what you need to do in order to prepare the correct data set. A good plan will help you with your analysis. Here are a few questions to get you staated?

# %% [markdown]
# 1. What is the performance metric you’ll use to evaluate the results of your test?
#
#     **I will be using the sum of gross margin as performance metric in order to evaluate the results of my test.**
#
# 2. What is the test period?
#
#     **The test will run for a period of 12 weeks (from 2016-04-29 – 2016-07-21).**
# 3. At what level (day, week, month, etc.) should the data be aggregated?
#
#     **The data should be aggregated at weekly level.**

# %% [markdown]
# ## Step 2: Clean Up Your Data
#
# In this step, you should prepare the data for steps 3 and 4. You should aggregate the transaction data to the appropriate level and filter on the appropriate data ranges. You can assume that there is no missing, incomplete, duplicate, or dirty data. You’re ready to move on to the next step when you have weekly transaction data for all stores.
#
# **In this step, I’ve done all the data cleansing steps, and there is no missing, incomplete, duplicate, or dirty data. I aggregated and filtered out the transaction data on the appropriate data ranges.
# To make sure that the transaction data is correctelly aggregated, I've verified the project anwser:**
#
# How many transactions did you get for Store 10018 in the week starting `2015-02-06`? (This is `YYYY-MM-DD` format, you might have a different date format)
#
# **The answer is 308.**

# %% [markdown]
# ![image.png](attachment:df9be401-da02-41c4-8a78-013c99ce39fb.png)

# %% [markdown]
# ## Step 3: Match Treatment and Control Units
#
# Apart from trend and seasonality…
#
#     1. What control variables should be considered? Note: Only consider variables in the RoundRoastersSoter file.
#
#    **In order to match Treatment and Control, we should consider `AvgMonthSales` and `Sq_Ft` variables.**
#
#     2. What is the correlation between each potential control variable and your performance metric?
#
#    **According to the Pearson Correlation Matrix, `AvgMonthSales` has high correlation of `0.98` with `Gross Margin` (performance matric, which is the sum of Gross Margin). We also see that `Sq_Ft` (Square Feet) has a week correlation of `-0.04` with Gross Margin.**

# %% [markdown]
# ![image.png](attachment:c965cbe3-3418-4526-9675-f964660bd447.png)

# %% [markdown]
#     3. What control variables will you use to match treatment and control stores?
#
# **`AvgMonthSales, Trend, and Seasonal` variables will be used as control variables to match treatment and control stores.**

# %% [markdown]
#     4. Please fill out the table below with your treatment and control stores pairs:

# %% [markdown]
# ![image.png](attachment:2e67031d-41c3-4fc7-97f8-1770104dcf9b.png)

# %% [markdown]
# ## Step 4: Analysis and Writeup
# Conduct your A/B analysis and create a short report outlining your results and recommendations. (250 words limit)
#
# Answer these questions. Be sure to include visualizations from your analysis:

# %% [markdown]
# 1. What is your recommendation - Should the company roll out the updated menu to all stores?
#
#     **I would recommend that the company should roll out the updated menu to all stores. The below plot shows the changes of treatment and control stores during test period.**
#
#  ![img](images/comparison.png)

# %% [markdown]
#  2. What is the lift from the new menu for West and Central regions (include statistical significance)?
#
#    **The lift from the new menu for West and Central regions are 39.98% and 42.1% respectively. They have a statistical significance of 99.96% and 98.64%.**
#
#    ![image.png](attachment:2445687f-3409-44b2-8ab3-8b10a462c8d8.png)
#
#    3. What is the lift from the new menu overall?

# %% [markdown]
# **From the new menu overall, the lift is 41.18% with statistical significance of 99.95%. Refer the last row of the above table**
